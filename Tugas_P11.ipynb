# %%
import pandas as pd

df_excel = pd.read_excel('disperkim-od_16985_jumlah_produksi_sampah_berdasarkan_kabupatenkota_v3_data.xlsx', sheet_name='data')
df_excel
# Out:
#       id  kode_provinsi nama_provinsi  kode_kabupaten_kota  \
# 0      1             32    JAWA BARAT                 3201
# 1      2             32    JAWA BARAT                 3202
# 2      3             32    JAWA BARAT                 3203
# 3      4             32    JAWA BARAT                 3204
# 4      5             32    JAWA BARAT                 3205
# ..   ...            ...           ...                  ...
# 238  239             32    JAWA BARAT                 3275
# 239  240             32    JAWA BARAT                 3276
# 240  241             32    JAWA BARAT                 3277
# 241  242             32    JAWA BARAT                 3278
# 242  243             32    JAWA BARAT                 3279
#
#     nama_kabupaten_kota  jumlah_produksi_sampah        satuan  tahun
# 0       KABUPATEN BOGOR                 1511.15  TON PER HARI   2015
# 1    KABUPATEN SUKABUMI                  419.01  TON PER HARI   2015
# ...

# %%
df_filter = df_excel[['nama_kabupaten_kota','jumlah_produksi_sampah','satuan','tahun']]
df_filter
# Out:
#     nama_kabupaten_kota  jumlah_produksi_sampah        satuan  tahun
# 0       KABUPATEN BOGOR                 1511.15  TON PER HARI   2015
# 1    KABUPATEN SUKABUMI                  419.01  TON PER HARI   2015
# 2     KABUPATEN CIANJUR                  981.41  TON PER HARI   2015
# 3     KABUPATEN BANDUNG                 1895.94  TON PER HARI   2015
# 4       KABUPATEN GARUT                  464.74  TON PER HARI   2015
# ..                  ...                     ...           ...    ...
# 238         KOTA BEKASI                     NaN  TON PER HARI   2023
# 239          KOTA DEPOK                     NaN  TON PER HARI   2023
# 240         KOTA CIMAHI                     NaN  TON PER HARI   2023
# 241    KOTA TASIKMALAYA                     NaN  TON PER HARI   2023
# 242         KOTA BANJAR                     NaN  TON PER HARI   2023
#
# [243 rows x 4 columns]

# %%
sampah_2021 = []

for index, row in df_excel.iterrows():
    if row['tahun'] == 2021:
        sampah_2021.append(row['jumlah_produksi_sampah'])

total_sampah_2021 = sum(sampah_2021)

dfsampah2021 = pd.DataFrame({'tahun': [2021], 'jumlah produksi sampah': [total_sampah_2021]})

dfsampah2021
# Out:
#    tahun  jumlah produksi sampah
# 0   2021                15735.36

# %%
print("List Jumlah Produksi Sampah Dari Kota Per Tahun")

# Inisialisasi dictionary untuk menampung total sampah per tahun
jumlah_sampah_per_tahun = {
    2015: 0,
    2016: 0,
    2017: 0,
    2018: 0,
    2019: 0,
    2020: 0,
    2021: 0,
    2022: 0,
    2023: 0
}

# Iterasi melalui DataFrame untuk mengisi total sampah per tahun
for index, row in df_excel.iterrows():
    tahun = row['tahun']
    if tahun in jumlah_sampah_per_tahun:
        jumlah_sampah_per_tahun[tahun] += row['jumlah_produksi_sampah']

# Membuat DataFrame untuk menampilkan hasil
df_total_sampah = pd.DataFrame(list(jumlah_sampah_per_tahun.items()), columns=['Tahun', 'Total Produksi Sampah'])

df_total_sampah
# Out:
# List Jumlah Produksi Sampah Dari Kota Per Tahun
#    Tahun  Total Produksi Sampah
# 0   2015               20969.27
# 1   2016               20969.27
# 2   2017               20969.27
# 3   2018               22772.92
# 4   2019               24490.56
# 5   2020               25333.00
# 6   2021               15735.36
# 7   2022                    NaN
# 8   2023                    NaN

# %%
total_wilayah_tahun = {}
for index, row in df_excel.iterrows():
    wilayah = row['nama_kabupaten_kota']
    tahun = row['tahun']
    jumlah = row['jumlah_produksi_sampah']
    
    if wilayah not in total_wilayah_tahun:
        total_wilayah_tahun[wilayah] = {}
    
    if tahun in total_wilayah_tahun[wilayah]:
        total_wilayah_tahun[wilayah][tahun] += jumlah
    else:
        total_wilayah_tahun[wilayah][tahun] = jumlah

result = []
for wilayah, tahun_data in total_wilayah_tahun.items():
     for tahun, jumlah in tahun_data.items():
         result.append([wilayah, tahun, jumlah])
         
df_result = pd.DataFrame(result, columns=('Wilayah','Tahun','Jumlah Sampah (Ton)'))
df_result
# Out:
# [['KABUPATEN BOGOR', 2015, 1511.15],
#  ['KABUPATEN BOGOR', 2016, 1511.15],
#  ['KABUPATEN BOGOR', 2017, 1511.15],
#  ['KABUPATEN BOGOR', 2018, 1716.8],
#  ['KABUPATEN BOGOR', 2019, 2914.65],
#  ['KABUPATEN BOGOR', 2020, 2977.0],
#  ['KABUPATEN BOGOR', 2021, 971.59],
#  ['KABUPATEN BOGOR', 2022, nan],
#  ['KABUPATEN BOGOR', 2023, nan],
#  ['KABUPATEN SUKABUMI', 2015, 419.01],
#  ['KABUPATEN SUKABUMI', 2016, 419.01],
#  ['KABUPATEN SUKABUMI', 2017, 419.01],
#  ['KABUPATEN SUKABUMI', 2018, 415.5],
#  ['KABUPATEN SUKABUMI', 2019, 1003.64],
#  ['KABUPATEN SUKABUMI', 2020, 1006.0],
#  ['KABUPATEN SUKABUMI', 2021, 356.02],
#  ['KABUPATEN SUKABUMI', 2022, nan],
#  ['KABUPATEN SUKABUMI', 2023, nan],
#  ['KABUPATEN CIANJUR', 2015, 981.41],
#  ['KABUPATEN CIANJUR', 2016, 981.41],
#  ['KABUPATEN CIANJUR', 2017, 981.41],
#  ['KABUPATEN CIANJUR', 2018, 965.19],
#  ['KABUPATEN CIANJUR', 2019, 1115.81],
#  ['KABUPATEN CIANJUR', 2020, 1117.0],
#  ['KABUPATEN CIANJUR', 2021, 355.69],
# ...
